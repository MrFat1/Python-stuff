# %%
def mostrar_pregunta(question, opciones):
    
    print("\nPregunta:\n", question)
    print("\nOpciones:")

    for i in range(len(opciones)):
        print("・", opciones[i])

# %%
import socket
import struct
import pickle
import threading

MCAST_GRP = '224.1.1.1'
MCAST_PORT = 5007
clientID = 'User 2'

sock = socket.socket(socket.AF_INET, socket.SOCK_DGRAM, socket.IPPROTO_UDP)

#Para unirse al grupo de multicast
sock.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)

#Listen only on the socket
sock.bind(('', MCAST_PORT))

msg = 'Joined the Game'
data_pack = (clientID, msg)
packed = pickle.dumps(data_pack)
sock.sendto(packed, (MCAST_GRP, MCAST_PORT))

#Tell the OS to add the socket to the multicast group
mreq = struct.pack("4sl", socket.inet_aton(MCAST_GRP), socket.INADDR_ANY)
sock.setsockopt(socket.IPPROTO_IP, socket.IP_ADD_MEMBERSHIP, mreq)

#Set TTL
ttl = struct.pack('b', 1)
sock.setsockopt(socket.IPPROTO_IP, socket.IP_MULTICAST_TTL, ttl)



quit = False

def recieve_function():
    global quit 
    while quit==False:
    
        try:
            packed = sock.recv(1024)
            data = pickle.loads(packed)

            if (str(data[1]) == "SERVER-QUESTION"):

                mostrar_pregunta(str(data[2]), data[3])


            if (str(data[1]) == 'END'):
                #Game ended, server OFF

                sock.close()
                quit = True

            print(str(data[0]) + ": " + str(data[1]))
            
        except(OSError):
            print("Socket closed")
            break
            
    print("FIN DEL JUEGO")

#Thread para recibir mensajes del server
reader = threading.Thread(target=recieve_function)
reader.start()

sock.sendto(pickle.dumps((clientID, "JOIN")) , (MCAST_GRP, MCAST_PORT))

while quit==False:
    msg = input("Introduce tu respuesta a la pregunta (Utiliza 'Quit' para salir en cualquier momento): ")
    
    try:
        #Server will take action upon recieving a Quit message from a certain User
        data_pack = (clientID, msg)
        packed = pickle.dumps(data_pack)
        sock.sendto(packed, (MCAST_GRP, MCAST_PORT))

        if (msg == "Quit"):

            sock.close()
            quit = True
            
    except(OSError):
        print("Socket closed")
        break
# Out:
# User 2: JOIN
# GameServer: User 2 joined the game.
# Introduce tu respuesta a la pregunta (Utiliza 'Quit' para salir en cualquier momento):
# User 2:
# GameServer: Waiting for a game to start...
# GameServer: Una nueva partida esta a punto de empezar!
#
# Pregunta:
#  In the Pok&eacute;mon series, what is Palkia&#039;s hidden ability?
#
# Opciones:
# ・ Pressure
# ・ Water Bubble
# ・ Hydration
# ・ Telepathy
# GameServer: SERVER-QUESTION
# User 1: Hydration
# GameServer: El usuario User 1 envió una respuesta incorrecta, la respuesta correcta era: Telepathy
# Ranking:
# #1 Usuario: User 1 Puntos: 0
# #2 Usuario: User 2 Puntos: 0
#
#
# Pregunta:
#  What were the Chilled Monkey Brains made from during Indiana Jones and the Temple of Doom?
#
# Opciones:
# ・ Strawberry Ice Cream
# ・ Cherry Yogurt
# ・ Raspberry Sorbet
# ・ Custard and Raspberry Sauce
# GameServer: SERVER-QUESTION
# Introduce tu respuesta a la pregunta (Utiliza 'Quit' para salir en cualquier momento): Custard and Raspberry Sauce
# User 2: Custard and Raspberry Sauce
# GameServer: User 2 envio la respuesta correcta, +1 punto
# Ranking:
# #1 Usuario: User 2 Puntos: 1
# #2 Usuario: User 1 Puntos: 0
#
#
# Pregunta:
#  What actor portrays Hogan &quot;Wash&quot; Washburne in the TV Show Firefly?
#
# Opciones:
# ・ Adam Baldwin
# ・ Nathan Fillion
# ・ Sean Maher
# ・ Alan Tudyk
# GameServer: SERVER-QUESTION
# User 1: Alan Tudyk
# GameServer: User 1 envio la respuesta correcta, +1 punto
# Ranking:
# #1 Usuario: User 1 Puntos: 1
# #2 Usuario: User 2 Puntos: 1
#
#
# Pregunta:
#  How many degrees Fahrenheit is 100 degrees Celsius?
#
# Opciones:
# ・ 326
# ・ 100
# ・ 451
# ・ 212
# GameServer: SERVER-QUESTION
# User 1: 212
# GameServer: User 1 envio la respuesta correcta, +1 punto
# Ranking:
# #1 Usuario: User 1 Puntos: 2
# #2 Usuario: User 2 Puntos: 1
#
#
# Pregunta:
#  In the movie &quot;Spaceballs&quot;, what are the Spaceballs attempting to steal from Planet Druidia?
#
# Opciones:
# ・ The Schwartz
# ・ Princess Lonestar
# ・ Meatballs
# ・ Air
# GameServer: SERVER-QUESTION
# User 1: The Schwartz
# GameServer: El usuario User 1 envió una respuesta incorrecta, la respuesta correcta era: Air
# Ranking:
# #1 Usuario: User 1 Puntos: 2
# #2 Usuario: User 2 Puntos: 1
#
# GameServer: GAME OVER
# Ranking:
# #1 Usuario: User 1 Puntos: 2
# #2 Usuario: User 2 Puntos: 1
#
# GameServer: Winnner: ('User 1', 2)
# GameServer: Waiting for a game to start...
# GameServer: Una nueva partida esta a punto de empezar!
#
# Pregunta:
#  Which director directed the movie &quot;Pan&#039;s Labyrinth&quot;?
#
# Opciones:
# ・ Alfonso Cuar&oacute;n
# ・ Alejandro Gonz&aacute;lez I&ntilde;&aacute;rritu
# ・  Alejandro Jodorowsky
# ・ Guillermo Del Toro
# GameServer: SERVER-QUESTION
# User 1: Si
# GameServer: El usuario User 1 envió una respuesta incorrecta, la respuesta correcta era: Guillermo Del Toro
# Ranking:
#
#
# Pregunta:
#  Slovakia is a member of European Union-
#
# Opciones:
# ・ False
# ・ True
# GameServer: SERVER-QUESTION
# User 1: True
# Introduce tu respuesta a la pregunta (Utiliza 'Quit' para salir en cualquier momento): Quit
# User 2: Quit
# FIN DEL JUEGO
